# %% [markdown]
# Name : P.Ganesh
#
# Rollno:21X05A6743
#
# Branch: CSE(DS)
#
# NRCM

# %% [markdown]
# **project title**
#
# # Analysis and predication of cancer patients rate in future using Linear Regression Algorithmof Machine Learning.

# %% [markdown]
# # ##problem statement : the organisation wants per hotel industries,consumer per spending tipS rupeesES per servent,by taking "RADIUS_MEAN","TEXTURE_MEAN"as a training data predict what was happen in a future for "COMPACTNESS_MEAN"

# %% [markdown]
# # #Tips:Findout the predicted values for "COMPACTNESS_MEAN",For training data,"TEXTURE_MEAN" vs "RADIUS_MEAN"

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("/content/CancerData.csv")
data
# Out:
#       id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      1         M        17.99         10.38          122.80     1001.0
# 1      2         M        20.57         17.77          132.90     1326.0
# 2      3         M        19.69         21.25          130.00     1203.0
# 3      4         M        11.42         20.38           77.58      386.1
# 4      5         M        20.29         14.34          135.10     1297.0
# ..   ...       ...          ...           ...             ...        ...
# 564  565         M        21.56         22.39          142.00     1479.0
# 565  566         M        20.13         28.25          131.20     1261.0
# 566  567         M        16.60         28.08          108.30      858.1
# 567  568         M        20.60         29.33          140.10     1265.0
# 568  569         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# ...

# %%
#test the data explicity with the features and o/p variable
x=data[["radius_mean","texture_mean"]] #input feature
y=data['compactness_mean'] #output variable
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.2,random_state=42)

# %%
model=LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
mse = mean_squared_error(y_test,y_pred)
print(f"mean squared error :{mse}")
# Out:
# mean squared error :0.001895613552713408

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test,y_pred,color='blue')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
